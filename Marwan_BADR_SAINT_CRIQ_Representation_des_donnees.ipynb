# %% [markdown]
# <a href="https://colab.research.google.com/github/SupremeWarMan/WEBSITE/blob/main/Marwan_BADR_SAINT_CRIQ_Representation_des_donnees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# |Eddy Labidi | <img width=230/> Representation des données <img width=230/>| <img src="https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_4/v1600275778/lyceelondres/q3q3xqfrko9gwz1m7f8k/Logo-Lycee.png" alt="logo" width="100"/>|
# | :--- |:---:| ---:|
# | Entrainement  | Langage Python | Lycée international de Londres  |

# %% [markdown]
# # Representation binaire

# %% [markdown]
# ## Q1
# Indiquer le nombre de valeurs decimale possibles sachant :
# N bits →  $2^n$ possibilités
#
# Quelles sont les 2 valeurs extrêmes que peut prendre en décimal un mot M de n bits non signé ?

# %%
nombre_bits = 2

# %% [markdown]
# ## Q2
#
# Quelles sont les 2 valeurs extrêmes que peut prendre en décimal un mot M de n bits signé ?
#
# Sachant que $ -2^{n-1} \leq M \leq 2^{n-1} - 1$

# %%
nombre_bits = 8

# %% [markdown]
# # Conversions

# %% [markdown]
# ## Q1
# Conversion binaire --> decimale

# %%
binaire = "101011111"

# %% [markdown]
# ## Q2
#
# Conversion decimale --> binaire

# %% [markdown]
# ### Solution 1

# %%
decimale =400000
binaire = ""

# %% [markdown]
# ### Solution 2

# %%
decimale = 5
binaire = ""
while decimale >= 2:
    binaire += str(decimale%2)
    decimale = decimale//2
binaire += str(decimale)

print(binaire[::-1])
# Out:
# 101

# %% [markdown]
# ### Solution 3

# %%
a = 5

# %% [markdown]
# ### Solution 4 (fonction recursive)

# %%
a = 5

# %% [markdown]
# # Conversion nombres relatifs

# %% [markdown]
# ## Q1
#
# Écrire un programme pour convertir un nombre décimal relatif, grâce à la méthode du complément à deux (8 bits)

# %% [markdown]
# ### Solution 1

# %%
decimale =-5
binaire = ""

# %% [markdown]
# ### Solution 2

# %% [markdown]
# Rappel : Bitwise operators
#
# Bitwise operators act on operands as if they were strings of binary digits. They operate bit by bit, hence the name.
#
# For example, 2 is 10 in binary and 7 is 111.
#
# In the table below: Let x = 10 (0000 1010 in binary) and y = 4 (0000 0100 in binary)
#
# |Operator |	Meaning |	Example |
# | :--- |:---:| ---:|
# | &  | Bitwise AND | x & y = 0 (0000 0000)  |
# | ~  | Bitwise NOT | ~x = -11 (1111 0101)  |
# | ^  | Bitwise XOR |  x ^ y = 14 (0000 1110) |
# |  >> | Bitwise right shift | x >> 2 = 2 (0000 0010)  |
# | <<  | Bitwise left shift | x << 2 = 40 (0010 1000)  |
#
# et pour finir
#  |   Bitwise OR   x | y = 14 (0000 1110)

# %%
a = -5

# %% [markdown]
# ### Solution 3

# %%
def decimale_signe_2bin(d,nb=0):
    """dec2bin(d,nb=0): conversion nombre entier relatif -> chaîne binaire (si nb>0,
    complète à gauche par des zéros pour les positifs et des uns pour les negatifs)"""

# %% [markdown]
# # Conversion de nombres flottants

# %% [markdown]
# ## Sans la norme IEEE 754
# Proposer un code pour convertir le nombre flottant suivant :

# %%
f =7.3

# %% [markdown]
# Le programme ci-dessus risque de ne jamais s'arreter si on utilise une variable double comme ci-dessous
#
# ![1.png](data:image/png;base64,...)

# %%
from decimal import Decimal
f = 2.367
f_double = Decimal(f)

print(f_double)

# %% [markdown]
# ## Avec la norme IEEE 754

# %% [markdown]
# ### Solution 1

# %%
f =-7.3

# %% [markdown]
# ### Solution 2

# %%
# Function for converting decimal to binary
# Out:
# ('0xC0E99999', '11000000111010011001100110011001')

# %% [markdown]
# # Encodage texte
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Code Ascii
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Code ASCII en tableau
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q1
# Programmer un code qui affiche le code décimale de n'importe quel caractère tapé au clavier puis afficher son code binaire en Unicode (UTF-8)

# %%
# Un programme pour afficher un caractère
code_decimale = 232
chr(code_decimale)
# Out:
# 'è'

# %%
caractere_saisi = "è"
decimale_caractere = ord(caractere_saisi)
print(f"Le Caractère '{caractere_saisi}' est representé par la valeur décimale {decimale_caractere}")
# Out:
# Le Caractère 'è' est representé par la valeur décimale 232
